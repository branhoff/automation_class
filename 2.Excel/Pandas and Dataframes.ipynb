# %% [markdown]
# pandas: https://pandas.pydata.org/pandas-docs/stable/

# %%
import pandas as pd

# %%
df = pd.read_excel("test.xlsx", sheet_name="ThisSheet")

# %%
df
# Out:
#            President             Birthday                 Hometown  \
# 0    Abraham Lincoln            2/12/1809          Springfield, IL
# 1  George Washington            2/22/1732         Mount Vernon, VA
# 2    Teddy Roosevelt  1919-01-06 00:00:00       New York, New York
# 3       Barack Obama  1961-08-04 00:00:00              Chicago, IL
# 4      James Madison            3/16/1751           Montpelier, VA
# 5     Andrew Johnson           12/29/1808  Elizabethton, Tennessee
# 6     Herbert Hoover            8/10/1874        West Branch, Iowa
# 7       Harry Truman             5/8/1884         Independence, Mo
#
#                      Wife
# 0               Mary Todd
# 1       Martha Washington
# 2         Edith Roosevelt
# 3          Michelle Obama
# 4          Dolley Madison
# 5  Eliza McCardle Johnson
# 6        Lou Henry Hoover
# 7             Bess Truman

# %%
sorted_df = df.sort_values(["President"])

# %%
sorted_df
# Out:
#            President             Birthday                 Hometown  \
# 0    Abraham Lincoln            2/12/1809          Springfield, IL
# 5     Andrew Johnson           12/29/1808  Elizabethton, Tennessee
# 3       Barack Obama  1961-08-04 00:00:00              Chicago, IL
# 1  George Washington            2/22/1732         Mount Vernon, VA
# 7       Harry Truman             5/8/1884         Independence, Mo
# 6     Herbert Hoover            8/10/1874        West Branch, Iowa
# 4      James Madison            3/16/1751           Montpelier, VA
# 2    Teddy Roosevelt  1919-01-06 00:00:00       New York, New York
#
#                      Wife
# 0               Mary Todd
# 5  Eliza McCardle Johnson
# 3          Michelle Obama
# 1       Martha Washington
# 7             Bess Truman
# 6        Lou Henry Hoover
# 4          Dolley Madison
# 2         Edith Roosevelt

# %%
sorted_df.to_excel("output.xlsx")
